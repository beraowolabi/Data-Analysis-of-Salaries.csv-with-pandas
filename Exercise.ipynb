# %% [markdown]
# # Load Salaries.csv as dataframe excluding "id" & "EmployeeName"

# %%
import pandas as pd

# %%
columns=list(pd.read_csv('Salaries.csv', nrows=1))
print(columns)
# Out:
# ['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency', 'Status']

# %%
sal=pd.read_csv('Salaries.csv',usecols= [i for i in range(2,13)]) # OR sal=pd.read_csv('Salaries.csv',usecols =[i for i in cols if i !='Id']) but I couldn't figure out a way to add a second column to be excluded using this line of code

# %%
sal
# Out:
#                                                 JobTitle    BasePay  \
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 5                              ASSISTANT DEPUTY CHIEF II  118602.00
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 7                         DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 11                       CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 12                           EXECUTIVE CONTRACT EMPLOYEE  294580.02
# ...

# %% [markdown]
# # Shuffle the dataset

# %%
sal=sal.sample(frac=1) #Tried using sal.shuffle() but kept getting errors despite upgrading numpy, downgrading it, installing sklearn, nothing made it work.

# %%
sal
# Out:
#                                               JobTitle    BasePay  \
# 110902                  Battalion Chief, Fire Suppress  178646.00
# 130846                               Legal Secretary 1   66876.63
# 121592                   Senior Administrative Analyst   98753.00
# 10611          PUBLIC SAFETY COMMUNICATIONS DISPATCHER   76260.37
# 121347                   Senior Administrative Analyst   98753.04
# 109165                    Public Svc Aide-Public Works    2155.93
# 84677                   Sr Airport Communications Disp   90174.70
# 38941                            Assistant Inspector 2  133544.34
# 102035                          Patient Care Assistant   21321.02
# 58225                            Media Production Tech   58045.68
# 9587                                    DEPUTY SHERIFF   86840.01
# 103015                                    Senior Clerk   17477.31
# 32280   PUBLIC SERVICE AIDE-ASSOCIATE TO PROFESSIONALS    7960.77
# ...

# %% [markdown]
# # Find the number of unique "JobTitle"

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# # Create a list of unique Job titles

# %%
list_job=list(sal['JobTitle'].unique())

list_job
# Out:
# ['Battalion Chief, Fire Suppress',
#  'Legal Secretary 1',
#  'Senior Administrative Analyst',
#  'PUBLIC SAFETY COMMUNICATIONS DISPATCHER',
#  'Public Svc Aide-Public Works',
#  'Sr Airport Communications Disp',
#  'Assistant Inspector 2',
#  'Patient Care Assistant',
#  'Media Production Tech',
#  'DEPUTY SHERIFF',
#  'Senior Clerk',
#  'PUBLIC SERVICE AIDE-ASSOCIATE TO PROFESSIONALS',
#  'Health Program Coordinator 3',
#  'Clinical Psychologist',
#  'Investigator/Transit Fare Supv',
#  'Transit Operator',
#  'Truck Driver',
#  'Management Assistant',
#  'FIREFIGHTER',
#  'Deputy Sheriff',
#  'Social Worker',
#  'POLICE OFFICER III',
#  'Custodian',
#  'Manager V',
#  'Legal Process Clerk',
#  'Special Examiner',
#  'Pr Administrative Analyst',
#  'Public Service Aide-Admin',
#  'AUTOMOTIVE MECHANIC',
#  'Automotive Mechanic',
#  'Senior Clerk Typist',
#  'Recreation Leader',
#  'Transit Car Cleaner',
#  'Camp Assistant',
#  'Senior Eligibility Worker',
#  'PAYROLL CLERK',
# ...

# %% [markdown]
# # Check if the "Notes" column is empty

# %%
sal['Notes'].empty # OR len(df.Notes.value_counts()) > 0
# Out:
# False

# %% [markdown]
# # Check for rows that have no missing columns

# %%
sal.dropna() #There are no rows without missing column values
# Out:
# Empty DataFrame
# Columns: [JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %% [markdown]
# # Find the Min and Max value of the following columns: "BasePay" "OvertimePay" "OtherPay" "TotalPaybenefits" (replace missing values by 0)

# %%
sal.BasePay.min()
# Out:
# -166.01

# %%
sal.BasePay.max()
# Out:
# 319275.01

# %%
sal['BasePay'].fillna(value=0)
# Out:
# 110902    178646.00
# 130846     66876.63
# 121592     98753.00
# 10611      76260.37
# 121347     98753.04
# 109165      2155.93
# 84677      90174.70
# 38941     133544.34
# 102035     21321.02
# 58225      58045.68
# 9587       86840.01
# 103015     17477.31
# 32280       7960.77
# 121457     98271.03
# 64518      29436.85
# 52920      73376.02
# 132332     49200.33
# 132853     65279.37
# 84050      99770.55
# 104317     13047.06
# 2615      105934.68
# 109523         0.00
# 80309      95119.50
# 96617      58088.40
# 4726      112421.40
# 104864     13724.81
# 112704    153619.00
# 102064     26843.15
# 72379        591.76
# 118577    114317.02
#             ...
# 8754       86840.01
# 119301     94191.00
# 40552     122742.73
# 118495    119805.61
# 75806     143289.09
# 75413     131197.01
# 100822     31932.42
# 23765      39590.86
# 51111      65155.06
# 42200      67035.21
# 91740      63980.35
# 28815      23060.53
# 144862      7693.64
# 116029    112164.03
# ...

# %%
sal.OvertimePay.min()
# Out:
# -0.01

# %%
sal.OvertimePay.max()
# Out:
# 245131.88

# %%
sal['OvertimePay'].fillna(value=0)
# Out:
# 110902    17003.15
# 130846        0.00
# 121592        0.00
# 10611     13114.98
# 121347        0.00
# 109165        0.00
# 84677      2467.09
# 38941     11277.77
# 102035     4979.88
# 58225       249.48
# 9587       6783.54
# 103015        0.00
# 32280         0.00
# 121457        0.00
# 64518         0.00
# 52920         0.00
# 132332     5568.19
# 132853     1597.39
# 84050         0.00
# 104317        0.00
# 2615      25719.37
# 109523        0.00
# 80309     18320.72
# 96617         0.00
# 4726       7785.86
# 104864        0.00
# 112704        0.00
# 102064      378.78
# 72379        34.81
# 118577        0.00
#             ...
# 8754       3700.01
# 119301     5258.64
# 40552         0.00
# 118495        0.00
# 75806      7674.42
# 75413     25361.18
# 100822     1798.31
# 23765      1499.82
# 51111     11645.47
# 42200     46794.42
# 91740      6044.45
# 28815         0.00
# 144862        0.00
# 116029    14964.21
# 89679     10814.20
# 49120         0.00
# ...

# %%
sal.OtherPay.min()
# Out:
# -7058.59

# %%
sal.OtherPay.max()
# Out:
# 400184.25

# %%
sal['OtherPay'].fillna(value=0)
# Out:
# 110902    12505.22
# 130846        0.00
# 121592        0.00
# 10611      5114.93
# 121347        0.00
# 109165       42.29
# 84677      5010.45
# 38941      9769.48
# 102035      397.27
# 58225       847.31
# 9587       5985.31
# 103015        0.00
# 32280         0.00
# 121457        0.00
# 64518      1226.90
# 52920       647.10
# 132332     6853.00
# 132853     2448.73
# 84050         0.00
# 104317        0.00
# 2615      13405.35
# 109523     1523.33
# 80309     10213.60
# 96617         0.00
# 4726       5892.46
# 104864      990.02
# 112704        0.00
# 102064      137.03
# 72379         0.00
# 118577        0.00
#             ...
# 8754      13405.50
# 119301    12185.15
# 40552      3486.00
# 118495        0.00
# 75806      7302.11
# 75413     11096.87
# 100822      737.41
# 23765     11806.56
# 51111       655.03
# 42200      6984.01
# 91740      1396.51
# 28815       695.55
# 144862        0.00
# 116029     7440.53
# 89679       648.00
# 49120      1140.00
# ...

# %%
sal.TotalPayBenefits.min()
# Out:
# -618.13

# %%
sal.TotalPayBenefits.max()
# Out:
# 567595.43

# %%
sal['TotalPayBenefits'].fillna(value=0)
# Out:
# 110902    261908.71
# 130846     96029.38
# 121592    134198.10
# 10611      94490.28
# 121347    135185.67
# 109165      2220.20
# 84677     130188.92
# 38941     192655.88
# 102035     37953.55
# 58225      87795.98
# 9587       99608.86
# 103015     27634.72
# 32280       7960.77
# 121457    134595.60
# 64518      42514.51
# 52920     106772.51
# 132332     90601.02
# 132853     88778.56
# 84050     133304.31
# 104317     17891.48
# 2615      145059.40
# 109523      1523.33
# 80309     157949.29
# 96617      83835.81
# 4726      126099.72
# 104864     14714.83
# 112704    209567.92
# 102064     37659.56
# 72379        677.93
# 118577    152597.41
#             ...
# 8754      103945.52
# 119301    147834.84
# 40552     175835.83
# 118495    152946.13
# 75806     199654.56
# 75413     206287.30
# 100822     52290.69
# 23765      52897.24
# 51111     113937.57
# 42200     163406.59
# 91740     101926.77
# 28815      23756.08
# 144862      7770.61
# 116029    172003.49
# ...

# %% [markdown]
# # Find the datatypes of all the loaded columns of the dataframe

# %%
sal.dtypes
# Out:
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %% [markdown]
# # Create a new column named "tax" where the values are 24% of "BasePay"

# %%
#df['Tax']=df[df['BasePay']*] # I haven't been able to figure this one out YET. My computer keeps showing:: OptionError: "No such keys(s): 'compute.use_numexpr'" for every code I try to use

# %% [markdown]
# # Create a new dataframe named "temp_df" where "BasePay" is greater than 100000

# %%
temp_df=sal[sal['BasePay']>100000]

# %%
temp_df
# Out:
#                                                  JobTitle    BasePay  \
# 110902                     Battalion Chief, Fire Suppress  178646.00
# 38941                               Assistant Inspector 2  133544.34
# 2615                                          FIREFIGHTER  105934.68
# 4726                                   POLICE OFFICER III  112421.40
# 112704                                          Manager V  153619.00
# 118577                          Pr Administrative Analyst  114317.02
# 81086                           Pr Administrative Analyst  115478.53
# 40106                                  IS Engineer-Senior  121524.03
# 1437                            CAPTAIN, FIRE SUPPRESSION  146649.31
# 80096                                    Registered Nurse  118974.80
# 111674                                        Firefighter  112703.73
# 81127                                             Plumber  102161.50
# 114239                                          Manager V  135168.38
# ...

# %% [markdown]
# # Answer the following using pandas:
#
# # How many agencies are in the dataset?

# %%
sal['Agency'].nunique()
# Out:
# 1

# %% [markdown]
# # How many years are accounted for in the dataset?

# %%
sal.Year.nunique() # OR sal.Year.unique() Out: array([2013, 2014, 2012, 2011], dtype=int64)
# Out:
# 4

# %% [markdown]
# # What is the average BasePay?

# %%
sal.BasePay.mean()
# Out:
# 66325.44884048768

# %% [markdown]
# # How many rows are the "OtherPay" greater than the "BasePay"

# %%
len(sal[sal['OtherPay']>sal['BasePay']])
# Out:
# 2218

# %% [markdown]
# # How many "JobTitle" observations have values of "not provided"

# %%
len(sal[sal['JobTitle']=='Not provided'])
# Out:
# 4
